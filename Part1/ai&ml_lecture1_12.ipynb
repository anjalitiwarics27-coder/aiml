# %% [markdown]
# #Earners AI ML by Aditya Jain sie -lecture 1.12

# %% [markdown]
# #Recap - String

# %%
s= "Anjali Tiwari"
for elem in s:
  print(elem)
# Out:
# A
# n
# j
# a
# l
# i
#
# T
# i
# w
# a
# r
# i

# %%
s="Tiwari"
type(s)
# Out:
# str

# %%
n=len(s)
print(n)
# Out:
# 6

# %%
s[2]
# Out:
# 'w'

# %%
s[-1]
# Out:
# 'i'

# %%
print(s)
# Out:
# Tiwari

# %%
s="Aditya Jain"

# %%
print(s)
# Out:
# Aditya Jain

# %%
a1=s[2:7]

# %%
print(a1)
# Out:
# itya

# %%
print(s[2:7])
# Out:
# itya

# %%
print(a1)
# Out:
# itya

# %%
print(s[:6])
# Out:
# Aditya

# %%
for elem in s:
  print(elem)
# Out:
# A
# d
# i
# t
# y
# a
#
# J
# a
# i
# n

# %%
n=len(s)
for i in range(n):
  print(s[i],end=" ")
# Out:
# A d i t y a   J a i n

# %%
print(s)
# Out:
# Aditya Jain

# %%
a=s.split(" ")
print(a)
# Out:
# ['Aditya', 'Jain']

# %%
s="Aditya Jain likes to do programming "
a=s.split(" ")
print(a)
# Out:
# ['Aditya', 'Jain', 'likes', 'to', 'do', 'programming', '']

# %%
for elm in a :
  print(elem)
# Out:
# n
# n
# n
# n
# n
# n
# n

# %%
for elem in a:
  print(elem)
# Out:
# Aditya
# Jain
# likes
# to
# do
# programming

# %% [markdown]
# ##HW -DPP-Tricky Advanced Questions

# %%
text="Programming"
count =0
for i in range(len(text)):
  if text[i] ==text[-1]:
    count+=1
print(count)
# Out:
# 2

# %%
word="Data"
result=" "
for ch in text:
  result=result+ch
print(result)
# Out:
#  Programming

# %%
word="Python"
i =len(word)-1
while i>=0:
  print(word[i],end=" ")
  i-=2
# Out:
# n h y

# %%
text="AI"
result=""
for i in range(4):
  result=result+text
print(result)
print(len(result))
# Out:
# AIAIAIAI
# 8

# %%
word="Computer"
count =0
for ch in word:
  if ch<"m":
    print(ch)
    count+=1
print(count)
# Out:
# C
# e
# 2

# %%
ord('A')
# Out:
# 65

# %%
ord('B')
# Out:
# 66

# %%
ord('Z')
# Out:
# 90

# %%
ord('a')
# Out:
# 97

# %%
ord('z')
# Out:
# 122

# %%
chr(122)
# Out:
# 'z'

# %%
chr(97)
# Out:
# 'a'

# %%
chr(65)
# Out:
# 'A'

# %%
chr(128522)
# Out:
# '😊'

# %%
text="Python"
result=""
for i in range(len(text)):
  if text[i]in"aeiouAEIOU":
    result +=text[i]
print(result)
# Out:
# o

# %%
word="LEVEL"
same=0
for i in range (len(word)):
  if(word[i]==word[-(i+1)]):
    print(i,-(i+1),"--->",word[i],word[-(i+1)])
    same +=1
print(same)
# Out:
# 0 -1 ---> L L
# 1 -2 ---> E E
# 2 -3 ---> V V
# 3 -4 ---> E E
# 4 -5 ---> L L
# 5

# %%
text="Python"
result=" "
for i in range(len(text)):
  if i<len(text) //2 :
    result +=text[i]
print(result)
# Out:
#  Pyt

# %% [markdown]
# ##Functions

# %%
print("Aditya")
# Out:
# Aditya

# %%
len("AJ")
# Out:
# 2

# %%
type(2)
# Out:
# int

# %%
# def function_name():
#   defination

# %%
def greet():
  print("Hello")

# %%
greet() #function call
# Out:
# Hello

# %%
#Write a function that prints "hello name" for whatever name you want

# %%
greet()
# Out:
# Hello

# %%
# code reusability
# function defination -->parameter
# function call -->argument

# %%
def greet(name):
  print("Hello",name)

# %%
greet("AJ")
# Out:
# Hello AJ

# %%
greet("Akshat")
# Out:
# Hello Akshat

# %%
greet("Anjali")
# Out:
# Hello Anjali

# %%
greet("Nidhi")
# Out:
# Hello Nidhi

# %%
greet("Aditya")
# Out:
# Hello Aditya

# %% [markdown]
# #Positional Arguments

# %%
def show(name,age):
  print("Nmae is ",name)
  print("Age is ", age)

# %%
show("Raj",22)
# Out:
# Nmae is  Raj
# Age is  22

# %%
show("Priya",20)
# Out:
# Nmae is  Priya
# Age is  20

# %%
show(20,"Raj")
# Out:
# Nmae is  20
# Age is  Raj

# %% [markdown]
# #Keyworded arguments

# %%
def show(name , age ):
  print("Name is ",name)
  print("Age is ",age)

# %%
show(name="Raj",age=20)
# Out:
# Name is  Raj
# Age is  20

# %%
show(age=20,name="Raj")
# Out:
# Name is  Raj
# Age is  20

# %% [markdown]
# #Return Keyword

# %%
def show(a,b):
  return a+b

# %%
s=show(2,3)
print(s)
# Out:
# 5

# %% [markdown]
# #Quiz

# %%
def greet():
  print("Hello")
greet()
# Out:
# Hello

# %%
greet()
# Out:
# Hello

# %%
def greet():
  print("Welcome")
greet()
greet()
# Out:
# Welcome
# Welcome

# %%
def add(a,b):
  print(a+b)
add(10,20)
# Out:
# 30

# %%
def square(n):
  return n*n
print(square(5))
# Out:
# 25

# %%
def message():
  print("Python")
x=message()
print(x)
# Out:
# Python
# None

# %%
def multiply(a,b):
  return a*b
result=multiply(4,5)
print(result)
# Out:
# 20

# %% [markdown]
# #HW

# %%
def check(num):
  if num%2==0:
    return "Even"
  else:
    return "Odd"
print(check(15))
# Out:
# Odd

# %%
def greet(name):
  print("Hello",name)
greet("Rahul")
# Out:
# Hello Rahul

# %%
def total(numbers):
  s=0
  for n in numbers:
    s+=n
  return s
print(total([5,10,15]))
# Out:
# 30

# %%
def display():
  return "Python"
print(display())
# Out:
# Python

# %%
def largest(a,b):
  if(a>b):
    return a
  else:
    return b
print(largest(12,25))
# Out:
# 25

# %%
def stars():
  print("*" * 5)
for i in range(3):
  stars()
# Out:
# *****
# *****
# *****
