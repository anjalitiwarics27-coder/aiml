# %% [markdown]
# ## Ai & ml by aditya jain - lecture 1.1

# %%
# Tentative Course Plane:
# 1. Python Essentials-->12
# 2. Python for ml and ai-->12
# 3. sql for ml and ai -->structured query language -->18
# 4. numpy-->python library for numerical python-->6
# 5. EDA using Pandas --> Efficiently deal with Tabular data using Python -->12
# 6. Data Visualization using python -->matplotlib ,seaborn -->6
# 7. probability & statistics -->12
# 8. classical ML-->classification , regression-->12
# 9. deep learning -->neural networks-->12
# 10. GenAI & Prompt Engineering -->LLM , Frameworks for prompt Engineering -->16
# 11. RAG,Agents ,MCP -->16
# 12. Project & Deployment -->4-5

# %% [markdown]
# ##Important Terminologies

# %%
# Algorithm -->step by step instructions to solve my problem
# Programing --> is a way of writing these instructions in a language that the computer understands.
# Programming Languages -->C,C++,Python,Java,JavaScript..
# why python ?-->
# 1. easy to understand -->programmer friendly
# 2. rich set of libraries -->ai,ml,web dev , automation ..
# hello world program-->c++ and python
# c++
# #include<iostream>
# using namespace std;
# int main(){
#     cout<<"hello world "<<endl;
# }
# python:
# print("hello world! ")

# syntax:
# "apple is aditya jain an eating "
# -------
# "Adity Jain is eating an Apple "
# what is syntax?
# grammatical rules for that particular programming language
# why google colab notebook ?
# 1. no installation
# 2. Free
# 3. Runs in Browser
# 4. used across industry

# %% [markdown]
# ##Basics of python Programming

# %%
print("Hello world ")
# Out:
# Hello world

# %%
print("welcome to Python ")
# Out:
# welcome to Python

# %%
print(welcome to python)
# Out:
#   File "/tmp/ipykernel_4314/2853779360.py", line 1
#     print(welcome to python)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A","B","C")
# Out:
# A B C

# %%
print(100)
# Out:
# 100

# %%
print(3+5)
# Out:
# 8

# %%
print(5-3)
# Out:
# 2

# %%
print(4*2)
# Out:
# 8

# %%
print(4/2)
# Out:
# 2.0

# %%
print("3+2")
# Out:
# 3+2

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# ##Quizes

# %%
# 1.which of the following is a common use of python?
# a.  al/ml
# b. datascience
# c. automation
# d. all of these
# ans : d

# %%
#2. What is Google Colab?
# A. A social media platform
# B. An online Python coding environment
# C. A gaming application
# D. A database
# ans : B

# %%
# What will be the output?
# print("Hello World")
# A.
# Hello World
# B.
# "Hello World"
# C.
# print("Hello World ")
# D. Error
# ans: A

# %% [markdown]
# ##HW

# %%
# 1. What will be printed?
# print(10)
# A. Ten
# B. "10"
# C. 10
# D. Error
#ans: c

# %%
# 2. Guess the output:
# print(5 + 3)
# Output?
# A. 53
# B. 8
# C. 5+3
# D. Error
# ans: B

# %%
print("Thanks! Hope it was usefull : ")
# Out:
# Thanks! Hope it was usefull :
