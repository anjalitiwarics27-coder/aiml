# %% [markdown]
# ##HW

# %%
print(10)
# Out:
# 10

# %%
print(5+3)
# Out:
# 8

# %%
print("5+3")
# Out:
# 5+3

# %%
print("Python")
print("sql")
# Out:
# Python
# sql

# %%
print("hello")
# Out:
# hello

# %%
print("hello)
# Out:
#   File "/tmp/ipykernel_2294/2149988476.py", line 1
#     print("hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A","B","C")
# Out:
# A B C

# %% [markdown]
# ##comments

# %%
this code print aj on the screen
print("aj")
# Out:
#   File "/tmp/ipykernel_2294/726053659.py", line 1
#     this code print aj on the screen
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#this code prints aj on the screen
print("AJ")
# Out:
# AJ

# %%
# #this code prints aj on the screen
# print("AJ")
# ctrl+/

# %%
#print("hello")
print("python")
# Out:
# python

# %% [markdown]
# ##variables

# %%
name="AJ"
city="nagpur"
id=24

# %%
print(name)
# Out:
# AJ

# %%
print(name)
# Out:
# AJ

# %%
print(id)
# Out:
# 24

# %%
print(city)
# Out:
# nagpur

# %%
print(City)
case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2294/2873433310.py in <cell line: 0>()
# ----> 1 print(City)
#
# NameError: name 'City' is not defined

# %%
# #variable naming rules
# 1.Start: Alphabet +
# 2. Middle or end ->Alphabet,_,digit

# %%
# me->yes
# _marks->yes
# City->yes
# States5->yes
# 4city->no
# Student-name->non

# %%
#variable_name=value

# %%
name="Aj"
city="nagpur"
state="maharastra"
id=24

# %%
#irst name="anjali" // not valid
firstName="anjali"
first_name="anjali"

# %%
college="RCOEM"
college="IIT bombay"
print(college)
# Out:
# IIT bombay

# %%
college="RCOEM"
print(college)
college="IIT bombay"
print(college)
# Out:
# RCOEM
# IIT bombay

# %%
#variable hamesa latest value store krta hein

# %% [markdown]
# ##Data Types

# %%
# 1.Integer-->integ:50,4,-6,0,22
# 2. Float ->decimal (also called double)
# eg:5.7,-4.5,3.6,2.0
# 3.String(text data)->str
# "aditya","nagpur","aditya jain"
# 4.boolean->True/False->bool

# %%
# "4"->str
# 5->int
# True->bool
# length=6.7->float

# %%
type("4")
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(6.7)
# Out:
# float

# %%
type("5.7")
# Out:
# str

# %%
type("True")
# Out:
# str

# %%
type(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2294/27329152.py in <cell line: 0>()
# ----> 1 type(false)
#
# NameError: name 'false' is not defined

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ##Taking input from the user

# %%
name="Aditya"

# %%
#input()

# %%
name=input()
# Out:
# aj

# %%
print(name)
# Out:
# aj

# %%
name=input("enter your name : ")
# Out:
# enter your name : aj

# %%
print(name)
# Out:
# aj

# %%
#q. take two int a sinput from the user and print their sum

# %%
num1=int(input("Enter ist number "))
num2=int(input("enter 2nd number "))
sum=num1+num2
print("sum :",sum)
# Out:
# Enter ist number 5
# enter 2nd number 7
# sum : 12

# %%
a=input()
# Out:
# 4

# %%
b=input()
# Out:
# 5

# %%
print(a+b)
# Out:
# 45

# %% [markdown]
# ##string concatenation

# %%
4+5
# Out:
# 9

# %%
"4"+"5"
# Out:
# '45'

# %%
"a"+"b"
# Out:
# 'ab'

# %%
# input()-->it is always taken as string

# %% [markdown]
# ##Type Casting

# %%
age ="20"
new_age=int(age) #typecasting
type(new_age)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
a=input()
b=input()
c=int(a)+int(b)
print(c)
# Out:
# 4
# 5
# 9

# %%
#mentos zindagi

# %%
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
# 5
# 6
# 11

# %%
#q. take year of birth as input and print the age

# %%
birth_year=int(input("enter your birth year :"))
age=2026-birth_year
print(age)
# Out:
# enter your birth year :2005
# 21

# %%
# q. take length and breath of the rectange as input and print its area

# %%
l=int(input("enter the len :"))
b=int(input("enter the breadth :"))
area= l*b
print(area)
# Out:
# enter the len :5
# enter the breadth :6
# 30

# %%
l=float(input())
b=float(input())
area=l*b
print(area)
# Out:
# 4.8
# 5.8
# 27.84

# %%
#q. take the name, age and height(in inches )of the student as input and print

# %%
name=input("enter the name : ")
age=int(input("enter the age : "))
height=float(input("enter the height :"))
print (name )
print(age)
print(height)
# Out:
# enter the name : anjali
# enter the age : 21
# enter the height :5.5
# anjali
# 21
# 5.5

# %%
name=input("enter the name : ")
age=int(input("enter the age : "))
height=float(input("enter the height :"))
print("--------------------------")
print (name , age,height )
# Out:
# enter the name : anjali
# enter the age : 21
# enter the height :5.5
# --------------------------
# anjali 21 5.5

# %% [markdown]
# ##quiz

# %%
# what is a varoable ?
# container for storing data

# %%
# which is a valid variable ?
# student_name

# %%
# data type of: type(100)--->int
# type("4.5")->str

# %%
# num1=input()
# num2=input()
# print(num1+num2)
# input:
# 10
# 20
# ans:1020

# %%
# is_student=True
# print(type(is_student))
# ans:<class 'bool'>

# %%
is_student=True
type(is_student)
# Out:
# bool

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
# print(type("python "))
# ans: <class'str'>

# %% [markdown]
# ##home-work

# %%
# name=int("enter your name :")
# ans: b
# take input from the user

# %%
# what data type is returned by input()?
# ans : str

# %%
# which function converts a string to an integer ?
# ans: int()
# option b
