# %% [markdown]
# #Earners AL ML by Aditya Jain sir -Lecture1.11

# %% [markdown]
# ##Recap

# %%
a=[4,6,7,2,1]

# %%
type(a)
# Out:
# list

# %%
n=len(a)
print(n)
# Out:
# 5

# %%
for i in range(n):
  print(a[i])
# Out:
# 4
# 6
# 7
# 2
# 1

# %%
for elem in a :
  print(elem)
# Out:
# 4
# 6
# 7
# 2
# 1

# %%
#Print the elements of the list in reverse order

# %%
for i in range(n-1,-1,-1):
  print(a[i])
# Out:
# 1
# 2
# 7
# 6
# 4

# %%
for i in range(n):
  print(a[n-1-i])
# Out:
# 1
# 2
# 7
# 6
# 4

# %% [markdown]
# #HW questions

# %%
numbers=[1,2,3,4]
for i in range(len(numbers)):
  numbers[i]=numbers[i]+i
print(numbers)
# Out:
# [1, 3, 5, 7]

# %%
numbers=[1,2,3,4]
n=len(numbers)
for i in range(n):
  numbers[i]=numbers[i]+i
print(numbers)
# Out:
# [1, 3, 5, 7]

# %%
marks=[65,75,85]
total=0
for n in marks:
  if(n>=70):
    total+=n
print(total)
# Out:
# 160

# %%
nums=[2,4,6]
nums[0]=nums[2]
nums[2]=nums[1]
print(nums)
# Out:
# [6, 4, 4]

# %%
names=["Amit","Neha","Raj"]
longest=names[0]
for name in names:
  if len(name)>len(longest):
    longest=name
print(longest)
# Out:
# Amit

# %%
names=["Amit","Neha","Raj","Aditya"]
longest=names[0]
for name in names:
  if len(name)>len(longest):
    longest=name
print(longest)
# Out:
# Aditya

# %%
names=["Amit","Neha","Raj","Shivani"]
longest=names[0]
for name in names:
  if len(name)>len(longest):
    longest=name
print(longest)
# Out:
# Shivani

# %%
data=[10,20,30]
for i in range(len(data)):
  data[i]=data[i]+10
print(max(data))
print(min(data))
# Out:
# 40
# 20

# %%
numbers=[5,10,15,20]
total=0
for i in range(len(numbers)):
  if(i%2==0):
    total+=numbers[i]
print(total)
# Out:
# 20

# %%
numbers=[5,10,15,20]
total=0
for i in range(len(numbers)):
  if(i%2==0):
    total=total+numbers[i]
  print(total)
# Out:
# 5
# 5
# 20
# 20

# %% [markdown]
# #List Slicing

# %%
a=[5,7,4,8,2,1,9]
print(a)
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[1:4])
# Out:
# [7, 4, 8]

# %%
print(a[2:5])
# Out:
# [4, 8, 2]

# %%
print(a[2:5])
# Out:
# [4, 8, 2]

# %%
print(a[:4])
# Out:
# [5, 7, 4, 8]

# %%
print(a[0:4])
# Out:
# [5, 7, 4, 8]

# %%
print(a[1:])
# Out:
# [7, 4, 8, 2, 1, 9]

# %%
print(a[:])
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
a
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[1:5:2])
# Out:
# [7, 8]

# %%
print(a[::2])
# Out:
# [5, 4, 2, 9]

# %% [markdown]
# #Strings

# %%
name="aj"

# %%
type(name)
# Out:
# str

# %%
a="24"
type(a)
# Out:
# str

# %%
email= "asitya@aj.com"

# %%
#empty string:
s=" "
print(s)

# %%
len(s)
# Out:
# 1

# %%
s=""
print(s)

# %%
len(s)
# Out:
# 0

# %%
name="Aditya"
print(name[0])
# Out:
# A

# %%
print(name[1])
# Out:
# d

# %%
print(name[-1])
# Out:
# a

# %%
# Print the given string in reverse order .

# %%
name="Aditya"
n=len(name)
for i in range(n):
  print(name[n-1-i],end=" ")
# Out:
# a y t i d A

# %%
name="Anjali"
for i in range (len(name)):
  print(name[len(name)-1-i],end=" ")
# Out:
# i l a j n A

# %%
print(name[1:4])
# Out:
# nja

# %%
print(name[::-1])
# Out:
# ilajnA

# %%
name="Shiavni"
n=len(name)
for i in range(n):
  print(name[::-1])
# Out:
# invaihS
# invaihS
# invaihS
# invaihS
# invaihS
# invaihS
# invaihS

# %%
name="Shiavni"
n=len(name)
print(name[::-1])
# Out:
# invaihS

# %%
print(name[::])
# Out:
# Shiavni

# %%
for i in range(n):
  print(name[i])
# Out:
# S
# h
# i
# a
# v
# n
# i

# %%
for elem in name:
  print(elem)
# Out:
# S
# h
# i
# a
# v
# n
# i

# %%
for c in name:
  print(c)
# Out:
# S
# h
# i
# a
# v
# n
# i

# %%
4+6
# Out:
# 10

# %%
"4"+"6"
# Out:
# '46'

# %%
"Aditya"+" Jain"
# Out:
# 'Aditya Jain'

# %% [markdown]
# #Quiz

# %%
word="Python"
print(word[3])
# Out:
# h

# %%
text="Machine"
print(text[-2])
# Out:
# n

# %%
name="Rahul"
print(len(name))
# Out:
# 5

# %%
first="Data"
second="Science"
print(first+second)
# Out:
# DataScience

# %%
print("AI"*3)
# Out:
# AIAIAI

# %%
" aj"*3
# Out:
# ' aj aj aj'

# %%
print("Aditya")
print("Jain")
# Out:
# Aditya
# Jain

# %%
print("Anjali")
print("-"*20)
print("Tiwari")
# Out:
# Anjali
# --------------------
# Tiwari

# %%
word="Python"
print("p"in word)
# Out:
# False

# %%
word="Python"
print("P"in word)
# Out:
# True

# %%
word="Python"
print("z"not in word)
# Out:
# True

# %%
word="Python"
print(word[0]+word[-1])
# Out:
# Pn

# %%
word="Python"
word[0]="J"
print(word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1282/2022263298.py in <cell line: 0>()
#       1 word="Python"
# ----> 2 word[0]="J"
#       3 print(word)
#
# TypeError: 'str' object does not support item assignment

# %%
#String are immutable -->cant be modified

# %%
a=[4,7,8]
a[1]=10
print(a)
# Out:
# [4, 10, 8]

# %%
word="Code"
for i in range(len(word)):
  print(i,word[i])
# Out:
# 0 C
# 1 o
# 2 d
# 3 e

# %%
text="Python"
i=0
while i <len(text):
  print(text[i])
  i+=2
# Out:
# P
# t
# o

# %%
word="Python"
count=0
for ch in word:
  if ch in"aeiouAEIOU":
    count+=1
print(count)
# Out:
# 1

# %%
word="Shivani"
count=0
for ch in word:
  if ch in"aeiouAEIOU":
    count+=1
print(count)
# Out:
# 3

# %%
text="Programming"
count=0
for ch in text:
  if(ch=="m"):
    count+=1
print(count)
# Out:
# 2

# %%
word="Python"
result=""
for ch in word:
  result=ch+result
print(result)
# Out:
# nohtyP

# %%
text="Data  Science"
spaces=0
for ch in text:
  if ch==" ":
    spaces+=1
print(spaces)
# Out:
# 2

# %%
word="Python"
total=0
for ch in word:
  total+=1
print(total==len(word))
# Out:
# True

# %% [markdown]
# #HW-DPP-Tricky Advanced Questions

# %%
text="Programming"
count=0
for i in range(len(text)):
  if text[i]==text[-1]:
    count+=1
print(count)
# Out:
# 2

# %%
word="Python"
rsult=""
for i in range(len(word)):
  if i%2==1:
    result+=word[i]
print(result)
# Out:
# nohtyPyhn

# %%
text="Data"
result=""
for ch in text:
  result=ch+result
print(result)
# Out:
# ataD

# %%
word="Machine"
count=0
for ch in word:
  if ch not in"aeiouAEIOU":
    count+=1
print(count)
# Out:
# 4

# %%
word="Python"
i=len(word)-1
while i>=0:
  print(word[i],end="")
  i-=2
# Out:
# nhy

# %%
text="AI"
Result=""
for i in range(4):
  result=result+text
print(len(result))
# Out:
# 12

# %%
word="Computer"
count=0
for ch in word:
  if ch<"m":
    count+=1
print(count)
# Out:
# 2

# %%
text="Python"
result=""
for i in range(len(text)):
  if text[i]in "aeiouAEIOU":
    result+=text[i]
print(result)
# Out:
# o

# %%
word="LEVEL"
same=0
for i in range(len(word)):
  if word[i]==word[-(i+1)]:
    same +=1
print(same)
# Out:
# 5
