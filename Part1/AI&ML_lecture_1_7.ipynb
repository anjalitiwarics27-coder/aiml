# %% [markdown]
# ##Quizes

# %%
for i in range (5):
  print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(4):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range (3,8):
  print(i)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(2,11,2):
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(10,0,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# which keyword is used to create a for loop?

# ans: for

# %%
for i in range(1,6):
  print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
for ch in "python":
  print(ch)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for ch in "python":
  print(ch , end = " ")
# Out:
# p y t h o n

# %%
for ch in "python":
  print(ch , end = "")
# Out:
# python

# %%
# which of the following is the correct syntax ?
# c--> for i in range(5):

# %%
for i in range(5,1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
for i in range(1,10,3):
  print(i)
# Out:
# 1
# 4
# 7

# %%
# how many times will the following loop execte?
# for i in range(1,11,2):
#   print(i)
# ans: B

# %%
for i in range(3,3):
  print(i)

# %%
# whic statement about range(start,stop)is True?
#  (c)start is included, stop is excluded

# %%
for i in range(4):
  print(i+10)
# Out:
# 10
# 11
# 12
# 13

# %%
for i in range(2):
  print("python")
  print("ai")
# Out:
# python
# ai
# python
# ai

# %%
for i in range(2):
  print("python")
print("Ai")
# Out:
# python
# python
# Ai

# %%
name ="data"
for ch in name:
  if ch=="a":
    print(ch)
# Out:
# a
# a

# %%
name ='data'
for ch in name:
  if ch!='a':
    print(ch)
# Out:
# d
# t

# %% [markdown]
# ##While Loop

# %%
## for loop mein hame pata hota h kab tak run hoga
#likn while loop mein kitne bar loop ko run krna hoga isliye ham while loop use krte hein

# %%
# 1. initialization
# 2. Condition
# 3. updation

# %%
#print all the int form 1 to 5
i=1
while(i<6):
  print(i)
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# write a while loop to print hi 7 times on the screen .
i=1
while(i<=7):
  print("hi")
  i=i+1
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
i=1
while(i<=7):
  print("hi",end=" ")
  i=i+1
# Out:
# hi hi hi hi hi hi hi

# %%
i=1
while(i<=7):
  print(i,"hi")
  i=i+1
# Out:
# 1 hi
# 2 hi
# 3 hi
# 4 hi
# 5 hi
# 6 hi
# 7 hi

# %%
i=1
while(i<=7):
  print(i,"hi")
  i+=1
# Out:
# 1 hi
# 2 hi
# 3 hi
# 4 hi
# 5 hi
# 6 hi
# 7 hi

# %%
i=7
while(i>=1):
  print(i,"hi")
  i-=1
# Out:
# 7 hi
# 6 hi
# 5 hi
# 4 hi
# 3 hi
# 2 hi
# 1 hi

# %%
#print all the even numbers b/w 0 to 10(both inclusive)using a while loop.
i=0
while(i<=5):
  print(2*i,"even")
  i=i+1
# Out:
# 0 even
# 2 even
# 4 even
# 6 even
# 8 even
# 10 even

# %%
i=0
while(i<=10):
  if(i%2==0):
    print(i,"even")
  i=i+1
# Out:
# 0 even
# 2 even
# 4 even
# 6 even
# 8 even
# 10 even

# %%
i=0
while(i<=10):
  print(i)
  i+=2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#print all the odd number 0 to 10

# %%
i=1
while(i<=10):
  print(i,"0dd")
  i+=2
# Out:
# 1 0dd
# 3 0dd
# 5 0dd
# 7 0dd
# 9 0dd

# %%
i=1
while(i<=10):
  if(i%2!=0):
    print(i,"0dd")
  i+=1
# Out:
# 1 0dd
# 3 0dd
# 5 0dd
# 7 0dd
# 9 0dd

# %%
i=1
sum=0
while(i<=3):
  sum=sum+i
  i+=1
print("sum: ",sum)
# Out:
# sum:  6

# %%
sum=0
for i in range (1,11):
  sum+=i
print("sum :",sum)
# Out:
# sum : 55

# %%
#n(n+1)/2
cal=0
n=int(input("enter the digit :"))
cal=(n*(n+1))/2
print("sum of the digit for nth term  :",cal)
# Out:
# enter the digit :10
# sum of the digit for nth term  : 55.0

# %%
i=1
n=int(input("enter the digit for table :"))
while(i<=10):
  print(n,"*",i,"=",n*i)
  i+=1
# Out:
# enter the digit for table :5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# ##Quiz + practice

# %%
count=1
while count <=3:
  print(count)
  count+=1
# Out:
# 1
# 2
# 3

# %%
count=5
while count<=10:
  print(count)
  count+=1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
count =10
while count>=8:
  print(count)
  count-=1
# Out:
# 10
# 9
# 8

# %%
# which statement is True about a while loop?
#  b)it runs as long as its contion is True

# %%
count=1
while count<1:
  print("hello")
# c . nothing

# %%
# which of the following is the correct syntax?
# c> while i<5:

# %%
num=2
while num<=8:
  print(num)
  num+=2
# Out:
# 2
# 4
# 6
# 8

# %%
count=5
while count >0:
  print(count)
  count-=2
# Out:
# 5
# 3
# 1

# %% [markdown]
# ##HW

# %%
count =1
while count<=5:
  count+=1
print(count)
# Out:
# 6

# %%
# which situation is best suited for a while loop?
# a> print numbers from 1 to 10.
# b> print multiplication table of 5 .
# c> keep asking for a password until the correct one is entered.
# d> print the first 20 even number.
# ans: c

# %%
x=0
while x<3:
  print(x)
  x+=1
print("done")
# Out:
# 0
# 1
# 2
# done

# %%
# count =1
# while count<=5:
#   print(count)
# infinite loop
