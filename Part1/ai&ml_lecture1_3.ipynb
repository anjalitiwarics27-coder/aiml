# %% [markdown]
# ##Recap

# %%
#variables
age=20
print(age)
# Out:
# 20

# %%
print(Age)
# case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2937/2955847039.py in <cell line: 0>()
# ----> 1 print(Age)
#
# NameError: name 'Age' is not defined

# %%
print("age")
# str
# Out:
# age

# %%
#datatype
type(10)
# Out:
# int

# %%
type(5.4)
# Out:
# float

# %%
type("aj")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
#typecasting
type("4.5")
# Out:
# str

# %%
a=input()
# Out:
# 6

# %%
type(a)
# Out:
# str

# %%
a=int(input())
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
len=float(input())
# Out:
# 5.7

# %%
type(len)
# Out:
# float

# %%
len =input()
# Out:
# 6.7

# %%
type(len)
# Out:
# str

# %% [markdown]
# ##operators

# %%
print(5+4)
# Out:
# 9

# %%
print(4-8)
# Out:
# -4

# %%
print(10*3)
# Out:
# 30

# %%
print(20/5)
# Out:
# 4.0

# %%
print(20/6)
# Out:
# 3.3333333333333335

# %%
# float division operator
print(20//6)
# Out:
# 3

# %%
print(10//5)
# Out:
# 2

# %%
print(10/5)
# float value return
# Out:
# 2.0

# %%
#modules -->gives remainder -->%
print(10%3)
# Out:
# 1

# %%
print(10%6)
# Out:
# 4

# %%
print(10%2)
# Out:
# 0

# %%
#power -->**
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %%
##calculator -->
#take two int as input from the user , and print +,-,/,//,%,**

# %%
num1 =int(input("enter num1 :"))
num2=int(input("enter num2 :"))
add=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2
floats_div=num1//num2
power=num1**num2
print("----------------------")
print(add,sub,mul,div,floats_div,power)
# Out:
# enter num1 :2
# enter num2 :3
# ----------------------
# 5 -1 6 0.6666666666666666 0 8

# %%
a=int(input())
b=int(input())
print("addition :",a+b)
print("subtraction :",a-b)
print("multiplication :",a*b)
print("division :",a/b)
print("floored division :",a//b)
print("modulus:",a%b)
print("power:",a**b)
# Out:
# 10
# 4
# addition : 14
# subtraction : 6
# multiplication : 40
# division : 2.5
# floored division : 2
# modulus: 2
# power: 10000

# %% [markdown]
# ##Assignment operators

# %%
x=10
print(x)
# Out:
# 10

# %%
x=10
x+=2#x=x+2
print(x)
# Out:
# 12

# %%
x=10
x-=4
print(x)
# Out:
# 6

# %%
x=10
x*=2
print(x)
# Out:
# 20

# %%
x=10
x/=2
print(x)
# Out:
# 5.0

# %%
x=10
x//=2
print(x)
# Out:
# 5

# %%
x=10
x%=2
print(x)
# Out:
# 0

# %%
x=10
x**=2
print(x)
# Out:
# 100

# %% [markdown]
# ##Comparison Operators

# %%
#result-->True and False

# %%
10>5
# Out:
# True

# %%
4<3
# Out:
# False

# %%
10>=7
# Out:
# True

# %%
5<=5
# Out:
# True

# %%
5<5
# Out:
# False

# %%
5==5
# Out:
# True

# %%
a=5

# %%
6==5
# Out:
# False

# %%
6!=5
# Out:
# True

# %%
7!=7
# Out:
# False

# %% [markdown]
# ##Logical Operators

# %%
# and , or , not

# %%
4>3
# Out:
# True

# %%
5>2
# Out:
# True

# %%
#multiple condtion in sngle condition

# %%
(4>3)and(5>2)
# Out:
# True

# %%
(4>3)and(5<2)
# Out:
# False

# %%
(4<3)and(5<2)
# Out:
# False

# %%
(4>3)or(5>2)
# Out:
# True

# %%
(4>3)or(5<2)
# Out:
# True

# %%
(4<3)or(5<2)
# Out:
# False

# %%
# not-->toggle
# True->False
# False->True

# %%
(4>7)
# Out:
# False

# %%
not(4>7)
# Out:
# True

# %%
not(4==5)
# Out:
# True

# %%
not(4!=7)
# Out:
# False

# %%
not((3>3)and(6<3))
# Out:
# True

# %%
not((3>3)or(6<3))
# Out:
# True

# %%
not((3>=3)or(6<3))
# Out:
# False

# %% [markdown]
# ##Membership Operator

# %%
#check it is in it or not

# %%
"a"in"aditya"
# Out:
# True

# %%
"b"in "aditya"
# Out:
# False

# %%
"c"not in "aditya"
# Out:
# True

# %%
"D"in "Aditiya"
# Out:
# False

# %%
"d"in "Aditya"
# Out:
# True

# %% [markdown]
# ##Quizes

# %%
print(10+5)
# Out:
# 15

# %%
print(20-8)
# Out:
# 12

# %%
print(6*4)
# Out:
# 24

# %%
print(15/3)
# Out:
# 5.0

# %%
print(17%5)
# Out:
# 2

# %%
print(4**2)
# Out:
# 16

# %%
print(20//3)
# Out:
# 6

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %%
salary=50000
salary-=10000
print(salary)
# Out:
# 40000

# %%
marks=40
print(marks>=40)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %% [markdown]
# ##HW

# %%
x=5
x+=3
x*=2
print(x)
# Out:
# 16

# %%
age=20
print(age>=18 and age<=60)
# Out:
# True
