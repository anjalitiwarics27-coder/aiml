# %% [markdown]
# ## Earners ai&ml -lecture1.4

# %%
type (10)
# Out:
# int

# %%
type(4.6)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
4!=6
# Out:
# True

# %%
5==5
# Out:
# True

# %%
(4!=6)or(5==5)
# Out:
# True

# %%
(4!=6)or(5!=5)
# Out:
# True

# %%
(4==6)or(5!=5)
# Out:
# False

# %%
(4!=6)and(5==5)
# Out:
# True

# %%
(4!=6)and(5!=5)
# Out:
# False

# %%
not(4!=6)
# Out:
# False

# %% [markdown]
# ## decision making

# %%
# sytanx:
# if condition:
#   statements.....

# %%
#given the  ag of the person, check they are eligible to vote. is age is atleast 20, them they are eligible

# %%
# age=int(input("enter the age "))
# if(age>=20):
#   print("eligible",age)
# else:
#   print("not eligile ", age)
# Out:
# enter the age 29
# eligible 29

# %%
#q2. take the paswd form the user . if it matches "hello@123"then print "welcome "
# user_password=input("enter the pasword ")
# if user_password=="hello@123":
#   print("welcome")
# Out:
# enter the pasword hello@123
# welcome

# %%
user_password=input("enter the pasword ")
if user_password=="hello@123":
  print("welcome")
else:
  print("invalid password")
# Out:
# enter the pasword hello
# wrong password

# %%
#else if condition

# %%
if (2>3):
  print("A")
else:
  print("B")
print("c")
# Out:
# B
# c

# %%
if (2<3):
  print("A")
else:
  print("B")
print("c")
# Out:
# A
# c

# %%
##elif
#marks =
#marks<30-> low
#marks b/w 31-70 ->
#marks>->high

# %%
# marks=int(input("enter the marks "))
# if (marks>30):
#   if(marks<=70):
#     print("avg")
#   else:
#     print("high")
# else:
#   print("low")
# Out:
# enter the marks 19
# low

# %%
# marks=20
# if marks< 30:
#   print("low ")
# else:
#   if(marks>=31)and(marks<=70):
#       print("avg")
#   else:
#       print("high")
# Out:
# low

# %%
# Use input() to catch user input, then convert it to an integer
marks = int(input("Enter the mark: "))

if marks < 30:
    print("low")
elif marks <= 70:  # This naturally covers 30 to 70 inclusive
    print("avg")
else:
    print("high")
# Out:
# Enter the mark: 39
# avg

# %%
#else if ==>elif
if 2<3:
  print("A")
elif 5>4:
  print("B")
else:
  print("C")
# Out:
# A

# %%
if 2>3:
  print("A")
elif 5>4:
  print("B")
else:
  print("C")
# Out:
# B

# %%
if 2>3:
  print("A")
elif 5<4:
  print("B")
else:
  print("C")
# Out:
# C

# %%
# marks=int(input("enter the marks "))
# if(marks<=30):
#   print("low")
# elif(marks>=30)and(marks<=70):
#   print("avg")
# else:
#   print("high")
# Out:
# enter the marks 75
# high

# %%
##coolest code
# marks=int(input("enter the marks "))
# if(marks<30):
#   print("low")
# elif(marks<=70):
#   print("avg")
# else:
#   print("high")
# Out:
# enter the marks 30
# avg
