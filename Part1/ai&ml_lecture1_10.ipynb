# %% [markdown]
# #Earners ai ml By Aditya Jain sir-1.10

# %% [markdown]
# ##Recap

# %%
for i in range(5):
  for j in range(6,10):
    print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %%
#What is the output?

for i in range(2):
  for j in range(2):
    print(j,end =" ")
  print()
# Out:
# 0 1
# 0 1

# %%
#which pattern will this code print ?
for row in range(4):
  for col in range(4):
    print("#",end=" ")
  print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
# what is the output?
for i in range(1,3):
  for j in range(1,3):
    print(i+j,end=" ")
  print( )
# Out:
# 2 3
# 3 4

# %%
for i in range(1,3):
  for j in range(1,3):
    print(i,"+",j,"=",i+j)
  print()
# Out:
# 1 + 1 = 2
# 1 + 2 = 3
#
# 2 + 1 = 3
# 2 + 2 = 4

# %% [markdown]
# #List

# %%
m1=90
m2=86
m3=95
m4=83
m5=70

# %%
marks=[90,88,95,83,70]

# %%
print(marks)
# Out:
# [90, 88, 95, 83, 70]

# %%
a=[45,'AJ',6.8,True]
print(a)
# Out:
# [45, 'AJ', 6.8, True]

# %%
print(a)
# Out:
# [45, 'AJ', 6.8, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %%
students=[]
print(students)
# Out:
# []

# %% [markdown]
# #Indexing

# %%
print(marks)
# Out:
# [90, 88, 95, 83, 70]

# %%
marks[0]
# Out:
# 90

# %%
marks[2]
# Out:
# 95

# %%
marks[4]
# Out:
# 70

# %%
n=len(marks)

# %%
print(n)
# Out:
# 5

# %%
marks[n-1]
# Out:
# 70

# %%
marks[n-2]
# Out:
# 83

# %%
marks[-1]
# Out:
# 70

# %%
marks[-2]
# Out:
# 83

# %%
marks[-3]
# Out:
# 95

# %%
#marks[5]
#indexErroe due to aout of range

# %%
marks
# Out:
# [90, 88, 95, 83, 70]

# %%
marks[2]=97

# %%
marks
# Out:
# [90, 88, 97, 83, 70]

# %% [markdown]
# ##Iterating over a list

# %%
for i in range(5):
  print(marks[i])
# Out:
# 90
# 88
# 97
# 83
# 70

# %%
for i in range(5):
  print(marks[i],end=" ")
# Out:
# 90 88 97 83 70

# %%
for elem in marks:
  print(elem)
# Out:
# 90
# 88
# 97
# 83
# 70

# %%
marks
# Out:
# [90, 88, 97, 83, 70]

# %%
#Write a code to print the elements present at even indexes

# %%
for i in range(5):
  if(i%2==0):
    print(marks[i])
# Out:
# 90
# 97
# 70

# %%
#write a code to print all the even elements

# %%
for i in range(n):
  if(marks[i]%2==0):
    print(marks[i])
# Out:
# 90
# 88
# 70

# %%
for elem in marks:
  if(elem%2==0):
    print(elem)
# Out:
# 90
# 88
# 70

# %% [markdown]
# #Quiz

# %%
#what is the output?
numbers=[10,20,30]
print(numbers[0])
# Out:
# 10

# %%
#What is the output?
fruits=["Apple","Banna","Mango"]
print(fruits[-1])
# Out:
# Mango

# %%
marks=[70,80,90]
print(len(marks))
# Out:
# 3

# %%
##what is the following is a valid python list?
#marks=[10,20,30]

# %%
#()->Tuple
#{}->set
#[]->list

# %%
numbers=[5,10,15,20]
print(numbers[-2])
# Out:
# 15

# %%
fruits=["Apple","Banana","Mango"]
fruits[1]="Orange"
print(fruits)
# Out:
# ['Apple', 'Orange', 'Mango']

# %%
number=[10,20]
print(numbers[2])
#list index out of bound
# Out:
# 15

# %%
numbers=[1,2,3]
for num in numbers:
  print(num)
# Out:
# 1
# 2
# 3

# %%
numbers=[10,20,30]
for num in numbers:
  print(num)
# Out:
# 10
# 20
# 30

# %%
numbers=[5,10,15]
for i in range(len(numbers)):
  print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# what is the output?
marks=[60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
marks=[60,70,80,90]
print(min(marks))
# Out:
# 60

# %%
marks=[60,70,80,90]
print(sum(marks))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1276/3144588443.py in <cell line: 0>()
#       1 marks=[60,70,80,90]
# ----> 2 print(sum(marks))
#
# TypeError: 'int' object is not callable

# %%
marks=[60,70,80,90]
total=0
for elem in marks:
  total=total+elem
print(total)
# Out:
# 300

# %%
# write a code to find the average of all the elments of the list:
marks=[60,70,80,90]
total =0
for elem in marks:
  total=total+elem
  avg=total/len(marks)
print(total)
print(avg)
# Out:
# 300
# 75.0

# %%
numbers=[9,5,7,1]
print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers
# Out:
# [9, 5, 7, 1]

# %%
numbers.sort()

# %%
print(numbers)
# Out:
# [1, 5, 7, 9]

# %%
names=["A","B","C"]
print(names[len(names)-1])
# Out:
# C

# %%
numbers = [5, 10, 15]

numbers[1] = numbers[0] + numbers[2]

print(numbers)
print(sum(numbers))
# Out:
# [5, 20, 15]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1276/2777973416.py in <cell line: 0>()
#       4
#       5 print(numbers)
# ----> 6 print(sum(numbers))
#
# TypeError: 'int' object is not callable

# %%
marks=[60,70,80,90]
for i in range(len(marks)):
  marks[i] = marks[i] + 5
print(marks)
# Out:
# [65, 75, 85, 95]

# %%
marks=[40,50,60,70,80,90]
for i in range(len(marks)):
  marks[i] = marks[i] + 5
print(marks)
# Out:
# [45, 55, 65, 75, 85, 95]

# %%
numbers=[8,2,5,1]
print(min(numbers))
print(max(numbers))
print(max(numbers)+min(numbers))
# Out:
# 1
# 8
# 9

# %%
items=[1,2,3]
for i in range(len(items)):
  items[i]=items[i]*2
print(sum(items))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1276/1430003345.py in <cell line: 0>()
#       2 for i in range(len(items)):
#       3   items[i]=items[i]*2
# ----> 4 print(sum(items))
#
# TypeError: 'int' object is not callable

# %%
numbers =[10.20,30]
print(numbers[-1]*100)
print(numbers)
# Out:
# 3000
# [10.2, 30]

# %%
numbers =[10,20,30]
numbers[-i]==100
print(numbers)
# Out:
# [10, 20, 30]

# %%
nums=[2,4,6,8]
count=0
for n in nums:
  if n>4:
    count+=1
print(count)
# Out:
# 2

# %%
marks=[80,75,90]
highest=max(marks)
for n in marks:
  print(highest-n)
# Out:
# 10
# 15
# 0

# %%
numbers=[3,5,7]
result=1
for n in numbers:
  result=result*n
print(result)
# Out:
# 105

# %%
values=[4,8,12]
i=0
while i<len(values):
  print(values[i]//2)
  i+=1
# Out:
# 2
# 4
# 6

# %% [markdown]
# #Hw

# %%
numbers=[1,2,3,4]
for i in range(len(numbers)):
  numbers[i]=numbers[i]+i
print(numbers)
# Out:
# [1, 3, 5, 7]

# %%
marks=[65,75,85]
total=0
for n in marks:
  if n>=70:
    total+=n
print(total)
# Out:
# 160

# %%
nums=[2,4,6]
nums[0]=nums[2]
nums[2]=nums[1]
print(nums)
# Out:
# [6, 4, 4]

# %%
names=["Amit","Neha","Raj"]
longest=names[0]
for i in names:
  if len(names)>len(longest):
    longest=names
print(longest)
# Out:
# Amit

# %%
names=["Amit","Neha","Raj","shivani"]
longest=names[0]
for i in names:
  if len(names)>len(longest):
    longest=names
print(longest)
# Out:
# Amit

# %%
numbers=[5,10,15,20]
total=0
for i in range(len(numbers)):
  if i%2==0:
    total+=numbers[i]
print(total)
# Out:
# 20
