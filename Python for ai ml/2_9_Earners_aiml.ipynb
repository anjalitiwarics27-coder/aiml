# %% [markdown]
# #DPP-Solutions

# %%
class Car:
  def __init__(self,brand):
    self.brand=brand
car1=Car("BMW")
car2=car1
car2.brand="Audi"
print(car1.brand)
# Out:
# Audi

# %%
print(car2.brand)
# Out:
# Audi

# %%
class Movie:
  def __init__(self,name):
    self.name=name
movie =Movie("Avatar")
print(hasattr(movie,"rating"))
# Out:
# False

# %%
class Student:
  def __init__(self):
    self.age=20
student=Student()
print(student.age+5)
# Out:
# 25

# %%
class Animal:
  def sound(self):
    print("Some Sound")
dog=Animal()
dog.sound()
dog.sound()
dog.sound()
# Out:
# Some Sound
# Some Sound
# Some Sound

# %%
class Laptop:
  def __init__(self,brand,ram):
    self.brand=brand
    self.ram=ram
laptop=Laptop("Dell",16)
print(laptop.brand,laptop.ram)
# Out:
# Dell 16

# %%
class Book:
  def __init__(self,title):
    self.title=title
book1=Book("Python")
book2=Book("SQL")
print(book1.title==book2.title)
# Out:
# False

# %%
class Book:
  def __init__(self,title):
    self.title=title
book1=Book("Python")
book2=Book("SQL")
print(book1.title)
print(book2.title)
print(book1.title==book2.title)
# Out:
# Python
# SQL
# False

# %%
class Student:
  def greet(self):
    return "Welcome"
student=Student()
message=student.greet()
print(message)
# Out:
# Welcome

# %%
class Bank:
  def __init__(self,balance):
    self.balance=balance
  def withdraw(self,amount):
    if amount<=self.balance:
      self.balance-=amount
account=Bank(1000)
account.withdraw(200)
account.withdraw(300)
print(account.balance)
# Out:
# 500

# %% [markdown]
# #Error Handling

# %%
Print("Hello") #NameError

# %%
print("Hello
#synatx  error

# %%
if 10>5
     print("Hello")
     #synatx error

# %%
if 10>5:
print("hello")
#indentation error

# %%
a=10
b=0
print(a/b)
#zero division error

# %%
a=0
b=10
print(a/b)
# Out:
# 0.0

# %%
a=[3,7,5]
print(a[4])
#index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_7764/440648527.py in <cell line: 0>()
#       1 a=[3,7,5]
# ----> 2 print(a[4])
#
# IndexError: list index out of range

# %%
age=int(input("Enter the age :"))
#value Error

# %%
# Write a code to take two numbers as input from the user and print their division .

# %%
a=int(input())
b=int(input())
print(a/b)
# Out:
# 4
# 6
# 0.6666666666666666

# %%
a=int(input())
b=int(input())
print(a/b)
# Out:
# 6
# 3
# 2.0

# %%
a=int(input())
b=int(input())
print(a/b)
# Out:
# 5
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_7764/228504323.py in <cell line: 0>()
#       1 a=int(input())
#       2 b=int(input())
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
#try block mein risky code ko likhte hein
#except uss error ko handle krta hein
try:
  n=int(input())
  print(100/n)
except:
  print("Some error has occured ")
# Out:
# 5
# 20.0

# %%
try:
  n=int(input())
  print(100/n)
except:
  print("Some error has occured ")
# Out:
# 0
# Some error has occured

# %%
try:
  n=int(input())
  print(100/n)
except:
  print("Some error has occured ")
print("Hello")
# Out:
# 4
# 25.0
# Hello

# %%
try:
  n=int(input())
  print(100/n)
except:
  print("cannot divide by 0 ")
# Out:
# 0
# cannot divide by 0

# %%
# disadvantage
try:
  n=int(input())
  print(100/n)
except:
  print("Cannot divide by 0")
# Out:
# Anjali
# Cannot divide by 0

# %%
try:
  a=[4,5,7]
  print(a[6])
except:
  print("Invalid index")
# Out:
# Invalid index

# %% [markdown]
# #Catching Specific Errors

# %%
try:
  n=int(input())
  print(100/n)
except Exception as e:
  print(e)
# Out:
# Anjali
# invalid literal for int() with base 10: 'Anjali'

# %%
try:
  n=int(input())
  print(100/n)
except Exception as e:
  print(e)
# Out:
# 0
# division by zero

# %%
try:
  n=int(input())
  print(100/n)
except ZeroDivisionError:
  print("Division by 0 is not allowed")
except ValueError:
  print("Please enter numbers only ")
# Out:
# Anjali
# Please enter numbers only

# %%
try:
  n=int(input())
  print(100/n)
except ZeroDivisionError:
  print("Division by 0 is not allowed")
except ValueError:
  print("Please enter numbers only ")
except Exception as e:
  print("Some error has occured ")

# %%
try:
  n=int(input())
  print(100/n)
except ZeroDivisionError:
  print("Division by 0 is not allowed")
except ValueError:
  print("Please enter numbers only ")
except Exception as e:
  print("Some error has occured ")

# %%
try:
  n=int(input())
  print(100/n)
  a=[3,6]
  print(a[4])
except ZeroDivisionError:
  print("Division by 0 is not allowed")
except ValueError:
  print("Please enter numbers only ")
except Exception as e:
  print("Some error has occured ")
# Out:
# 5
# 20.0
# Some error has occured

# %%
try:
  n=int(input())
  print(100/n)
  a=[3,6]
  print(a[4])
except Exception as e:
  print("Some error has occured ")
except ZeroDivisionError:
  print("Division by 0 is not allowed ")
except ValueError:
  print("Please enter numbers only ")
# Out:
# 5
# 20.0
# Some error has occured

# %%
try:
  n=int(input())
  print(100/n)
  a=[3,6]
  print(a[4])
except Exception as e:
  print("Some error has  occured !")
except ZeroDivisionError:
  print("Division by 0 is not allowed ")
except ValueError:
  print("Please enter numbers only ")
# Out:
# adit
# Some error has  occured !

# %%
try:
  n=int(input())
  print(100/n)
  a=[3,6]
  print(a[4])
except Exception as e:
  print("Some Error has occured ")
except ZeroDivisionError:
  print("Division by 0 is not allowed ")
except ValueError:
  print("Please enter numbers only")
# Out:
# 5
# 20.0
# Some Error has occured

# %%
# else block runs when no exception occurs
try:
  num=int(input())
except ValueError:
  print("Invalid Input")
else:
  print("You entered :",num)
# Out:
# 5
# You entered : 5

# %%
# else block runs only when no except occures
try:
  num=int(input())
except ValueError:
  print("Invalid Input")
else:
  print("You entered :",num)
# Out:
# adit
# Invalid Input

# %%
# finally block always excutes irrespective whether there is an error or not

# %%
try:
  num=int(input())
except ValueError:
  print("Invalid Input")
finally:
  print("Program Finised")
# Out:
# 4
# Program Finised

# %%
#finally block always executes irrespective whether these is an error or not

# %%
try:
  num=int(input())
except ValueError:
  print("Invalid Input")
finally:
  print("Program Finished")
# Out:
# adit
# Invalid Input
# Program Finished

# %% [markdown]
# ##Quiz

# %%
try:
  print(10/2)
except:
  print("Error")
# Out:
# 5.0

# %%
try:
  print(10/0)
except:
  print("Cannot divide")
# Out:
# Cannot divide

# %%
numbers=[10,20,30]
print(numbers[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1050/2320395797.py in <cell line: 0>()
#       1 numbers=[10,20,30]
# ----> 2 print(numbers[5])
#
# IndexError: list index out of range

# %%
student={
    "name":"Rahul"
}
print(student["age"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1050/3091980456.py in <cell line: 0>()
#       2     "name":"Rahul"
#       3 }
# ----> 4 print(student["age"])
#
# KeyError: 'age'

# %%
try:
  print("Python")
except:
  print("Error")
finally:
  print("Done")
# Out:
# Python
# Done

# %%
try:
  n=int("a")
except:
  print("Python")
else:
  print("Done")
# Out:
# Python

# %%
# what is the purpose of the finally block?
# A. Runs only when there is no exception
# B. Runs only when an exception occures
# C.Always Executes
# D. stops the program
# ans: c

# %%
try:
  print(100/25)
except:
  print("Error")
else:
  print("Success")
# Out:
# 4.0
# Success

# %%
try:
  x=5
  print(x)
except Exception:
  print("Error")
# Out:
# 5

# %%
try:
  a=20
  b=0
  result=a/b
  print(result)
except ZeroDivisionError:
  print("Cannot divide")
finally:
  print("Program Finised")
# Out:
# Cannot divide
# Program Finised

# %% [markdown]
# ##DPP-Questions

# %%
try:
  numbers=[5,10,15]
  index=2
  print(numbers[index])
except IndexError:
  print("Wrong Index")
else:
  print("Done")
# Out:
# 15
# Done

# %%
try:
  age=int("Twenty")
  print(age)
except ValueError:
  print("Invalid Age")
finally:
  print("End")
# Out:
# Invalid Age
# End

# %%
try:
  student={
      "name":"Rahul",
      "marks":90
  }
  print(student["age"])
except KeyError:
  print("key missing")
print("Program End")
# Out:
# key missing
# Program End

# %%
try:
  num=int("25")
  print(100/num)
except ValueError:
  print("Value Error")
except ZeroDivisionError:
  print("Division Error")
else:
  print("Calculation Done")
# Out:
# 4.0
# Calculation Done

# %%
try:
  numbers=[2,4,6]
  print(numbers[5])
except IndexError:
  print("Index Error")
except Execution:
  print("Gernal Error")
finally:
  print("Finished")
# Out:
# Index Error
# Finished

# %%
try:
  value=int("50")
  print(value)
except Exception:
  print("Error")
else:
  print("Sucess")
finally:
  print("Done")
# Out:
# 50
# Sucess
# Done
