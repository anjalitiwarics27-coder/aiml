# %% [markdown]
# #Earners ai and ml by Aditya Jain Sir - Lecture 19

# %% [markdown]
# ##OOP using Python

# %%
# Class -->Blueprint
# Object -->Specific instance of that class

# %%
name="Raj"
age=20
city="Mumbai"

# %%
name1="Rahul"
age1= 25
city1="Delhi"

# %%
name3="Ayushi"
age3=21
city3="Pune"

# %%
# Before manufacturing the car , the company would finalize the template.
#Features of that car that should be present in its blueprint:
# 1.Brand
# 2.sqft area
# 3.location

# %% [markdown]
# ##Class creation

# %%
class student:
  pass #placeholder-->do nothing

# %%
class student:
  name="Raj"
  age=21
  city="Mumbai"

# %%
class student:
  name="Raj"
  age=21
  city="Mumbai"

# %%
s1=student()

# %%
print(s1.name)

# %%
print(s1.city)

# %%
s2=student()

# %%
print(s2.name)

# %%
print(s2.name)

# %%
print(s2.city)

# %%
class student:
  name
  age
  city

# %%
s1=student()

# %%
s2.name="Raj"
s2.age=21
s2.city="Mumbai"

# %%
s2=student()
s2.name="Ayushi"
s2.age=20
s2.city="Pune"

# %%
print(s1.name,s2.name)

# %%
#this repetitive problem can be solved using __init__()

# %%
class student:
  def __init__():
    print("Student Object has got created !")

# %%
s1=student()

# %%
class student:
  def __init__(self):
    print("Student object has got created!")

# %%
s1=student()

# %%
class student:
  def __init__(self,name):
    self.name=name

# %%
s1=student("Raj")

# %%
s1.name

# %%
s2=student("Rahul")
print(s2.name)

# %%
s3=student("Ayushi")
print(s3.name)

# %%
class student:
  def __init__(self,name,age,city):
    self.name=name
    self.age=age
    self.city=city

# %%
s1=student("Raj",21,"Mumbai")
s2=student("Rahul",20," Pune")
s3=student("Ayushi",22,"Delhi")

# %%
s1.display_profile()

# %%
s2.display_profile()

# %% [markdown]
# #Mini-Case Study

# %%
# A bank wants to build a simple system to manage customer accounts using Object-Oriented Programming (OOP).
# Create a class named BankAccount with the following requirements:
# Requirements
# The class should have a constructor (__init__) that accepts:
# Account holder's name (holder)
# Initial account balance (balance)
# Create a method named deposit(amount) that adds the given amount to the account balance.
# Create a method named withdraw(amount) that:
# Deducts the given amount from the balance if sufficient funds are available.
# Otherwise, displays the message:
# Insufficient Balance
# Create a method named show_balance() that displays the current account balance

# %%
class BankAccount:
  def __init__(self, holder, balance):
    self.holder = holder
    self.balance = balance
  def deposit(self, amount):
    self.balance += amount
  def withdraw(self, amount):
    if amount > self.balance:
      print("Insufficient Balance")
    else:
      self.balance -= amount
  def show_balance(self):
    print(self.balance)

# %%
bank_acc1=BankAccount("Raj",1000)

# %%
bank_acc1.balance

# %%
bank_acc1.show_balance()

# %%
bank_acc1.withdraw(2000)

# %%
bank_acc1.show_balance()

# %%
bank_acc1.withdraw(200000)

# %% [markdown]
# #Quiz

# %%
# What is the output?
# class Student:
#   pass
# s = Student()
# print(type(s))
# A.
# <class 'Student'>
# B.
# <class '__main__.Student'>
# C.
# Student
# D. Error

# %%
class Student:
  pass
s = Student()
print(type(s))

# %%
# How do you create an object of the class Car?
# A.
# Car
# B.
# Car[]
# C.
# Car()
# D.
# new Car()

# %%
# What is the output?
# class Student:
#   pass
# s1 = Student()
# s2 = Student()
# print(s1 == s2)
# A. True
# B. False
# C. None
# D. Error

# %%
class Student:
  pass
s1 = Student()
s2 = Student()
print(s1 == s2)

# %%
# What is the purpose of the __init__() method?
# A. Deletes an object
# B. Initializes an object when it is created
# C. Prints an object
# D. Stops the program

# %%
class Student:
  def __init__(self):
    print("Student Created")
s = Student()

# %%
class Student:
  def __init__(self, name):
    self.name = name
s = Student("Rahul")
print(s.name)

# %%
# What is self?
# A. Name of the class
# B. Current object
# C. Constructor
# D. Function name

# %%
# What is the output?
class Car:
  def __init__(self, brand):
    self.brand = brand
car = Car("BMW")
print(car.branded)

# %%
class Student:
  def __init__(self, name):
    self.name = name
s1 = Student("Rahul")
s2 = Student("Neha")
print(s2.name)

# %%
class Employee:
  def __init__(self, salary):
    self.salary = salary
emp = Employee(50000)
emp.salary = 60000
print(emp.salary)

# %% [markdown]
# #Hw

# %%
class Mobile:
  def __init__(self, brand):
    self.brand = brand
m = Mobile("Samsung")
print(hasattr(m, "brand"))

# %%
# What is the output?
class Student:
  def show(self):
    print("Python")
s = Student()
print(type(s))
# A.
# <class '__main__.Student'>
# B.
# Student
# C.
# Python
# D. Error

# %%
# What is the output?
class Book:
  def __init__(self, title):
    self.title = title
b = Book("Python Basics")
print(len(b.title))

# %%
# What is the output?
class Rectangle:
  def __init__(self, length, width):
    self.length = length
    self.width = width
  def area(self):
    return self.length * self.width
r = Rectangle(5, 4)
print(r.area())

# %%
# What is the output?
class Circle:
  def __init__(self, radius):
    self.radius = radius
c1 = Circle(5)
c2 = Circle(10)
print(c1.radius + c2.radius)

# %%
# What is the output?
class Laptop:
  def __init__(self, brand):
    self.brand = brand
  def display(self):
    print(self.brand)
l = Laptop("Dell")
l.display()
l.display()

# %%
class Bank:
  def __init__(self, balance):
    self.balance = balance
  def deposit(self, amount):
    self.balance += amount
account = Bank(1000)
account.deposit(500)
print(account.balance)

# %%
class Student:
  def __init__(self, name, marks):
    self.name = name
    self.marks = marks
  def result(self):
    if self.marks >= 40:
      print("Pass")
    else:
      print("Fail")
s = Student("Rahul", 35)
s.result()

# %%
class student:
  def __init__(self, name):
self.name = name
def change_name(self, new_name):
self.name = new_name
s = Student("Rahul")
s.change_name("Amit")
print(s.name)

# %%
class Counter:
  def __init__(self):
    self.count = 0
  def increase(self):
    self.count += 1
c = Counter()
for i in range(5):
  c.increase()
print(c.count)
