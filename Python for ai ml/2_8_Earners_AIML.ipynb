# %% [markdown]
# ##Earners aiml by aditya jain sir -lecture no. 2.8

# %% [markdown]
# #OOP Recap

# %%
class Student:
  def __init__(self,name,age):
    self.name=name
    self.age= age

# %%
s1=Student("Raj",22)

# %%
print(s1.age)
# Out:
# 22

# %%
s2=Student("Anjali",23)

# %%
print(s2.name)
# Out:
# Anjali

# %%
print(s2.age)
# Out:
# 23

# %%
class Student:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def show(self):
    print("name :",self.name,"age:",self.age)

# %%
s1=Student("Raj",22)

# %%
s2=Student("Anjali",23)

# %%
s1.show()
# Out:
# name : Raj age: 22

# %%
s2.show()
# Out:
# name : Anjali age: 23

# %% [markdown]
# ##HW

# %%
class Mobile:
  def __init__(self,brand):
    self.brand=brand
m=Mobile("Samsung")
print(hasattr(m,"brand"))
# Out:
# True

# %%
print(hasattr(m,"name"))
# Out:
# False

# %%
class Student:
  def show(self):
    print("Python")
s=Student()
print(type(s))
# Out:
# <class '__main__.Student'>

# %%
class Book:
  def __init__(self,title):
    self.title=title
b=Book("Python Basics")
print(len(b.title))
# Out:
# 13

# %%
b.title
# Out:
# 'Python Basics'

# %%
class Rectangle:
  def __init__(self,lenght,width):
    self.lenght=lenght
    self.width=width
  def area(self):
    return self.lenght*self.width
r=Rectangle(5,4)
print(r.area())
# Out:
# 20

# %%
class Circle:
  def __init__(self,radius):
    self.radius=radius
  def area(self):
    return 3.14*self.radius*self.radius
c=Circle(5)
print(c.area())
# Out:
# 78.5

# %%
class Circle:
  def __init__(self,radius):
    self.radius=radius
c1=Circle(5)
c2=Circle(10)
print(c1.radius+c2.radius)
# Out:
# 15

# %%
class Laptop:
  def __init__(self,brand):
    self.brand=brand
  def display(self):
    print(self.brand)
l=Laptop("Dell")
l.display()
l.display()
# Out:
# Dell
# Dell

# %%
class Bank:
  def __init__(self,balance):
    self.balance=balance
  def deposit(self,amount):
    self.balance+=amount
account =Bank(1000)
account.deposit(500)
print(account.balance)
# Out:
# 1500

# %%
class Student:
  def __init__(self,name,marks):
    self.name=name
    self.marks=marks
  def result(self):
    if self.marks>=40:
      print("Pass")
    else:
      print("Fail")
s=Student("Rahul",35)
s.result()
# Out:
# Fail

# %%
s1=Student("Raj",45)
s1.result()
# Out:
# Pass

# %%
class Student:
  def __init__(self,name):
    self.name=name
  def charge_name(self,new_name):
    self.name=new_name
s=Student("Rahul")
print(s.name)
s.charge_name("Amit")
print(s.name)
# Out:
# Rahul
# Amit

# %%
class Counter:
  def __init__(self):
    self.count=0
  def increase(self):
    self.count+=1
c=Counter()
for i in range(5):
  c.increase()
print(c.count)
# Out:
# 5

# %% [markdown]
# #class variable and instance variable

# %%
class Student:
  college="IIT Bombay"
  def __init__(self,name):
    self.name=name
  def show_name(self):
    print(self.name)
s1=Student("Anjali")
print(s1.name)
# Out:
# Anjali

# %%
print(s1.name,s1.college)
# Out:
# Anjali IIT Bombay

# %%
s2=Student("Shivani")
print(s2.name)
# Out:
# Shivani

# %%
print(s2.name,s2.college)
# Out:
# Shivani IIT Bombay

# %% [markdown]
# ##Inheritance

# %%
# parent class --> the class we are inheriting from -->base class
# child class --> the class that inherits from another class -->derived class

# %%
class Person:
  def __init__(self,first_name,last_name):
    self.first_name =first_name
    self.last_name=last_name
  def show_name(self):
    print(self.first_name,self.last_name)

# %%
p1=Person("Raj","Sharma")
p1.show_name()
# Out:
# Raj Sharma

# %%
class Student(Person):
  pass

# %%
s1=Student("Raj","Sharma")
s1.show_name()
# Out:
# Raj Sharma

# %%
# Create a parent class vehicle with an __init__method that takes brand as input
# Add a method display_brand() that prints the vehicle's brand.
# create a child class Car that inherits from Vehicle .

# %%
class Vehicle:
  def __init__(self,brand):
    self.brand=brand
  def display_brand(self):
    print("Brand of the Car is ",self.brand)

# %%
class Car(Vehicle):
  pass

# %%
c1=Car(Vehicle)

# %%
c1=Car("Suzuki")

# %%
c1.display_brand()
# Out:
# Brand of the Car is  Suzuki

# %%
class Vehicle:
  def __init__(self,brand):
    self.brand=brand
  def display_brand(self):
    print("Brand of the Car is",self.brand)

# %%
class Car(Vehicle):
  car_engine = "kia_1"

# %%
c2=Car("Kia")

# %%
c2.display_brand()
# Out:
# Brand of the Car is Kia

# %%
c2.car_engine
# Out:
# 'kia_1'

# %% [markdown]
# #Polymorphism

# %%
s = "Aditya"

# %%
Ist=[3,5,8,1]
len(Ist)
# Out:
# 4

# %%
d={"name " :"Raj","age":22,"city":"Mumbai"}
len(d)
# Out:
# 3

# %%
1+2 # addition
# Out:
# 3

# %%
"a"+"b" #concatenation
# Out:
# 'ab'

# %% [markdown]
# #DPP-Questions

# %%
class Car:
  def __init__(self,brand):
    self.brand=brand
car1=Car(" BMW")
car2=car1
car2.brand="Audi"
print(car1.brand)
# Out:
# Audi

# %%
class Student:
  pass
s1=Student()
s2=Student()
s3=s2

# %%
class Movie:
  def __init__(self,name):
    self.name=name
movie=Movie("Avatar")
print(hasattr(movie,"rating"))
# Out:
# False

# %%
class Student:
  def __init__(self):
    self.age =20
student=Student()
print(student.age+5)
# Out:
# 25

# %%
class Laptop:
  def __init__(self,brand,ram):
    self.brand=brand
    self.ram=ram
laptop=Laptop ("Dell",16)
print(laptop.brand,laptop.ram)
# Out:
# Dell 16

# %%
class Book:
  def __init__(self,title):
    self.title=title
book1=Book("Python")
book2=Book("Sql")
print(book1.title==book2.title)
# Out:
# False

# %%
class Bank:
  def __init__(self,balance):
    self.balance=balance
  def withdraw(self,amount):
    if amount<=self.balance:
      self.balance-=amount
account=Bank(1000)
account.withdraw(200)
account.withdraw(300)
print(account.balance)
# Out:
# 500
