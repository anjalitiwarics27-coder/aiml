# %% [markdown]
# #Earnres AI ML by Aditya Jain sir-2.2

# %% [markdown]
# ##Recap -Dictionary

# %%
student={
    "name":"Raj",
    "marks":95,
    "city":"Mumbai"
}

# %%
print(student)
# Out:
# {'name': 'Raj', 'marks': 95, 'city': 'Mumbai'}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'Raj'

# %%
student["marks"]
# Out:
# 95

# %%
student["city"]
# Out:
# 'Mumbai'

# %%
student[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4064/3657199547.py in <cell line: 0>()
# ----> 1 student[0]
#
# KeyError: 0

# %%
student.get(0)

# %%
student.get("city")
# Out:
# 'Mumbai'

# %%
student.get("state","key not found ")
# Out:
# 'key not found '

# %%
student.get("city","key not found")
# Out:
# 'Mumbai'

# %%
for k in student:
  print(k)
# Out:
# name
# marks
# city

# %%
for k in student.keys():
  print(k)
# Out:
# name
# marks
# city

# %%
for v in student.values():
  print(v)
# Out:
# Raj
# 95
# Mumbai

# %%
for k in student.keys():
  print(student[k])
# Out:
# Raj
# 95
# Mumbai

# %%
for item in student.items():
  print(item)
# Out:
# ('name', 'Raj')
# ('marks', 95)
# ('city', 'Mumbai')

# %%
for item in student.items():
  print(item)
# Out:
# ('name', 'Raj')
# ('marks', 95)
# ('city', 'Mumbai')

# %% [markdown]
# #HW

# %%
fruit={
    "Apple":50,
    "Banana":20
}
fruit["Apple"] +=fruit["Banana"]
print(fruit["Apple"])
print(fruit["Banana"])
# Out:
# 70
# 20

# %%
student={
    "Math":90,
    "Science":85,
    "English":95
}
highest=0
for subject in student:
  if student[subject]>highest:
    highest=student[subject]
print(highest)
# Out:
# 95

# %%
student={
    "name":"Rahul",
    "age":22
}
student["age"]=student["age"]+len(student)
print(student["age"])
# Out:
# 24

# %%
data={}
data["A"]=10
data["B"]=20
data["A"]=30
print(len(data))
# Out:
# 2

# %%
data={}

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 0

# %%
data={}
data["A"]=10
data["B"]=20
data["A"]=30
print(len(data))
# Out:
# 2

# %%
student={
    "Math":80,
    "Scienece":90,
    "English":85
}
count=0
for key in student:
  if student[key]>=85:
    count+=1
print(count)
# Out:
# 2

# %%
person={
    "name":"Amit",
    "age":25
}
person.pop("age")
person["age"]=30
print(person)
# Out:
# {'name': 'Amit', 'age': 30}

# %%
marks={
    "Math":90,
    "Science":80,
    "English":70
}
total=0
for subject in marks:
  if marks[subject]>=80:
    total+=marks[subject]
print(total)
# Out:
# 170

# %%
student ={
    "Math":95,
    "Science":85
}
for key in student:
  print(key,student[key]//10)
# Out:
# Math 9
# Science 8

# %%
95//10
# Out:
# 9

# %%
95/10
# Out:
# 9.5

# %%
85/10
# Out:
# 8.5

# %%
85//10
# Out:
# 8

# %%
data={
    "A":5,
    "B":10,
    "C":15
}
result=0
for key in data:
  if data[key]%10==0:
    result+=1
print(result)
# Out:
# 1

# %%
student={
    "Math":90,
    "science":80
}
student["Total"]=0
for key in student:
  if key!="Total":
    student["Total"]+=student[key]
print(student["Total"])
# Out:
# 170

# %% [markdown]
# #Tuples

# %%
days=["Monday","Tuesday","Wednesday","Thrusday","Friday","Saturday","Sunday"]
days[0]="AJ Day"

# %%
days
# Out:
# ['AJ Day', 'Tuesday', 'Wednesday', 'Thrusday', 'Friday', 'Saturday', 'Sunday']

# %%
days=("Monday","Tuesday","Wednesday","Thrusday","Friday","Saturday","Sunday")

# %%
days[0]="AJ Day"
#Tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4064/154532769.py in <cell line: 0>()
# ----> 1 days[0]="AJ Day"
#       2 #Tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
a=("AJ",9.9,24,True)
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 24

# %%
b=()
len(b)
# Out:
# 0

# %%
type(b)
# Out:
# tuple

# %%
c=(1)
type(c)
# Out:
# int

# %%
(3+5)
# Out:
# 8

# %%
d=(1,)

# %%
type(d)
# Out:
# tuple

# %%
a
# Out:
# ('AJ', 9.9, 24, True)

# %%
print(a[1])
# Out:
# 9.9

# %%
print(a[-1])
# Out:
# True

# %%
print(a[-2])
# Out:
# 24

# %% [markdown]
# #Traversing Tuples

# %%
for elem in a :
  print(elem)
# Out:
# AJ
# 9.9
# 24
# True

# %%
n=len(a)
for i in range(n):
  print(a[i])
# Out:
# AJ
# 9.9
# 24
# True

# %%
a
# Out:
# ('AJ', 9.9, 24, True)

# %%
print(a[1:3])
# Out:
# (9.9, 24)

# %%
b=("p","q","r")
print("p"in b)
# Out:
# True

# %%
b=("p","q","r")
print("a" not in b )
# Out:
# True

# %%
num=(2,4,5)
print(sum(num))
# Out:
# 11

# %%
num=(2,3,5)
print(sum(num))
# Out:
# 10

# %%
num=(2,3,5)
print(min(num))
# Out:
# 2

# %%
num=(2,4,5,4)
print(num.count(4))
# Out:
# 2

# %%
num.index(4)
# Out:
# 1

# %% [markdown]
# #Packing and Unpacking

# %%
student=("Raj",9.9,24)

# %%
type(student)
# Out:
# tuple

# %%
# unpacking
name,cgpa, age= student

# %%
print(name)
# Out:
# Raj

# %%
print(cgpa)
# Out:
# 9.9

# %%
print(age)
# Out:
# 24

# %%
name,cgpa,age=("Raj",9.9,24)
print(name,age,cgpa)
# Out:
# Raj 24 9.9

# %%
def show():
  return 2,3

# %%
a=show()
print(a)
# Out:
# (2, 3)

# %% [markdown]
# # Quiz

# %%
numbers=(10,20,30,40)
print(numbers[2])
# Out:
# 30

# %%
fruits=("Apple","Banana","Mango")
print(fruits[-2])
# Out:
# Banana

# %%
t=(5)
type(t)
# Out:
# int

# %%
t=(5,)
type(t)
# Out:
# tuple

# %%
numbers=(15,25,5,40)
print(max(numbers))
# Out:
# 40

# %%
numbers=(15,25,5,40)
print(min(numbers))
# Out:
# 5

# %%
marks=(80,85,90)
print(sum(marks))
# Out:
# 255

# %%
numbers=(1,2,3,3,2)
print(numbers.count(2))
# Out:
# 2

# %%
fruits=("Apple","Banana","Mango")
print(fruits.index("Banana"))
# Out:
# 1

# %%
colors=("Red","Green","Blue")
for color in colors:
  print(color)
# Out:
# Red
# Green
# Blue

# %%
colors=("Red","Banana","Mango")
print("Banana"in fruits)
# Out:
# True

# %%
fruits=("Apple","Banana","Mango")
print("Banana" not in fruits)
# Out:
# False

# %%
numbers=(10,20,30)
numbers[1]=50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4064/3772989081.py in <cell line: 0>()
#       1 numbers=(10,20,30)
# ----> 2 numbers[1]=50
#
# TypeError: 'tuple' object does not support item assignment

# %%
name="Raj"
name[i]="e"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4064/3267385918.py in <cell line: 0>()
#       1 name="Raj"
# ----> 2 name[i]="e"
#
# TypeError: 'str' object does not support item assignment

# %%
numbers=(5,10,15,20)
total=0
for num in numbers:
  if num%10==0:
    total+=num
print(total)
# Out:
# 30

# %%
marks=(80,90,70,100)
highest=marks[0]
for mark in marks:
  if mark>highest:
    highest=mark
print(highest)
# Out:
# 100

# %%
fruits=("Apple","Banana","Mango")
for i in range(len(fruits)):
  if i%2==0:
    print(fruits[i])
# Out:
# Apple
# Mango

# %%
numbers=(2,4,6)
result=1
for num in numbers:
  result*=num
print(result+len(numbers))
# Out:
# 51

# %%
numbers=(2,4,6)
result=0
for num in numbers:
  result*=num
print(result+len(numbers))
# Out:
# 3

# %%
student=("Rahul",85,90,95)
name=student[0]
average=sum(student[1:])/len(student[1:])
print(name,average)
# Out:
# Rahul 90.0

# %%
student=("Rahul",85,90,95)
name=student[0]
average=sum(student[1:])/3
print(name,average)
# Out:
# Rahul 90.0

# %%
student[1:]
# Out:
# (85, 90, 95)

# %%
sum(student[1:])
# Out:
# 270

# %%
sum(student[1:])/3
# Out:
# 90.0

# %%
data=("Python","Java","C++")
count=0
for item in data:
  if len(item)>4:
    count+=1
print(count)
# Out:
# 1

# %% [markdown]
# #HW

# %%
values=(5,10,15,20)
total=0
for value in values:
  if value%5==0:
    total+=value//5
print(total)
# Out:
# 10

# %%
colors=("Red","Green","Blue")
for color in colors:
  print(color[0],end=" ")
print()
# Out:
# R G B

# %%
numbers=(1,2,3)
a,b,c=numbers
print(a+b*c)
# Out:
# 7

# %%
marks=(80,90,95)
bonus=()
for mark in marks:
  bonus.append(mark+5)
print(bonus)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4064/298046812.py in <cell line: 0>()
#       2 bonus=()
#       3 for mark in marks:
# ----> 4   bonus.append(mark+5)
#       5 print(bonus)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
fruits=("Apple","Banana","Mango")
for fruit in fruits:
  if "a" in fruit.lower():
    print(fruit)
# Out:
# Apple
# Banana
# Mango

# %%
numbers=(10,20,30,40)
smallest=min(numbers)
largest=max(numbers)
print(largest-smallest)
# Out:
# 30

# %%
prices=(100,200,150)
discount=()
for p in prices:
  discount+=(p-20,)
print(sum(discount))
# Out:
# 390

# %%
tuple1=(1,2)
tuple2=(3,4)
tuple3=tuple1+tuple2
print(tuple3*2)
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
data=(2,4,6,8)
count=0
for num in data:
  if num%4==0:
    count+=1
print(count)
# Out:
# 2
