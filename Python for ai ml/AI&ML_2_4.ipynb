# %% [markdown]
# # Earners Ai Ml by Aditya Jain sir - Lecture 16

# %% [markdown]
# ##For Ml-AI:Wed to Sunday

# %% [markdown]
# ###Questions

# %%
def fun (values):
  total=0
  for v in values:
    if v%2==0:
      total+=v
  return total
numbers=[5,8,12,7,10]
print(fun(numbers))
# Out:
# 30

# %%
student={
    "Math":80,
    "Science":90,
    "English":85
}
count=0
for subject in student:
  if student[subject]>=85:
    count+=1
print(count)
# Out:
# 2

# %%
#Print the subject where the marks scored atleast as
student={
    "Math":80,
    "Science":90,
    "English":85
}
sub=[]
for v in student:
  if student[v]>=85:
    sub.append(v)
print(sub)
# Out:
# ['Science', 'English']

# %%
names=["Rahul","Amit","Neha","Riya"]
answer=""
for name in names:
  if len(name)==4:
    print(name,name[-1])
    answer+=name[-1]
print(answer)
# Out:
# Amit t
# Neha a
# Riya a
# taa

# %%
numbers=(10,15,20,25)
result=()
for n in numbers:
  if n%5==0:
    result+=(n//5,)
print(result)
# Out:
# (2, 3, 4, 5)

# %%
# numbersers=(10,15,20,25)
# result=()
# for n in numbers:
#   if n%5==0:
#     result+=(n//5)
# print(result)

# %%
numbers=(10,15,20,25)
result=(0)
for n in numbers:
  if n%5==0:
    result+=(n//5)
print(result)
# Out:
# 14

# %%
a=(4)
type(a)
# Out:
# int

# %%
a=(4,)
type(a)
# Out:
# tuple

# %%
a=[4]
type(a)
# Out:
# list

# %%
values={2,4,6,8}
total =0
for value in values:
  total+=value
print(total//len(values))
# Out:
# 5

# %%
type(values)
# Out:
# set

# %%
numbers=[3,6,9]
new=[]
for n in numbers:
  new.append(n*n)
print(max(new))
# Out:
# 81

# %%
student=("Rahul",22,95)
name,age,marks=student
if marks>90:
  grade="A"
else:
  grade="B"
print(name,grade)
# Out:
# Rahul A

# %%
student=[3,6,9]
new=[]
for n in numbers:
  new.append(n*n)
print(max(new))
# Out:
# 81

# %%
student=("Rahul",22,95)
name,age,marks=student
if marks>90:
  grade="A"
else:
  grade="B"
print(name,grade)
# Out:
# Rahul A

# %%
student=("Rahul",22,95)
name,marks=student
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1510/1492495646.py in <cell line: 0>()
#       1 student=("Rahul",22,95)
# ----> 2 name,marks=student
#
# ValueError: too many values to unpack (expected 2)

# %%
student("Rahul",22,95)
name,age,marks,grade=student
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1510/1635814718.py in <cell line: 0>()
# ----> 1 student("Rahul",22,95)
#       2 name,age,marks,grade=student
#
# TypeError: 'tuple' object is not callable

# %%
fruits=["Apple","Banana","Mango"]
result=[]
for fruit in fruits:
  if len(fruit)>5:
    result.append(fruit.upper())
print(result)
# Out:
# ['BANANA']

# %%
data={
    "A":5,
    "B":10,
    "C":15
  }
total=0
for key in data:
  total+=data[key]
print(total/len(data))
# Out:
# 10.0

# %%
data={
    "A":5,
    "B":10,
    "C":15
}
total=0
for key in data:
  total+=data[key]
print(total//len(data))
# Out:
# 10

# %%
numbers=[2,4,6,8]
i=0
total=0
n=len(numbers)
while i<n:
  total+=numbers[i]
  i+=2
print(total)
# Out:
# 8

# %%
text="Mississippi"
count={}
for ch in text:
  if ch not in count:
    count[ch]=1
  else:
    count[ch]+=1
print(count["s"])
# Out:
# 4

# %%
words={"cat","elephant","dog","tiger"}
longest= words[0]
for word in words:
  if len(word)>len(longest):
    longest=word
print(longest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1510/1577802121.py in <cell line: 0>()
#       1 words={"cat","elephant","dog","tiger"}
# ----> 2 longest= words[0]
#       3 for word in words:
#       4   if len(word)>len(longest):
#       5     longest=word
#
# TypeError: 'set' object is not subscriptable

# %%
student={
    "Rahul":90,
    "Amit":75,
    "Neha":85
}
highest_name=""
highest_marks=0
for name in student:
  if student[name]>highest_marks:
    highest_marks=student[name]
    highest_name=name
print(highest_name)
# Out:
# Rahul

# %% [markdown]
# #Set

# %%
students=[
    "Rahul",
    "Amit",
    "Rahul"
    "Neha",
    "Amit",
    "Rahul"
    ]
print(students)
# Out:
# ['Rahul', 'Amit', 'RahulNeha', 'Amit', 'Rahul']

# %%
type(students)
# Out:
# list

# %%
#Write a code to only store the unique occurance of the elements in the list.
students=[
    "Rahul",
    "Amit",
    "Rahul"
    "Neha",
    "Amit",
    "Rahul"
    ]
s1=[]
if student in students:
  if student not in s1:
    s1.append(student)
print(s1)
# Out:
# []

# %%
#set:
# 1. stores only the unique values
# 2. unordered
# 3. mutable(add/remove elements )

# %%
num={3,6,8,2,1}
type(num)
# Out:
# set

# %%
fruits={"Apple","Banana","Mango"}
len(fruits)
# Out:
# 3

# %%
num={4,5,7,2,4,8,1}
len(num)
# Out:
# 6

# %%
s={4,5.5,"aj",False}
type(s)
# Out:
# set

# %%
L=[]
t=()
d={}

# %%
type(d)
# Out:
# dict

# %%
s=set()
type(s)
# Out:
# set

# %%
len(s)
# Out:
# 0

# %%
num={4,5,7,2,4,8,1}
print(num)
# Out:
# {1, 2, 4, 5, 7, 8}

# %%
num[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1510/3703492311.py in <cell line: 0>()
# ----> 1 num[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for n in num:
  print(n)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
num.add(10)
print(num)
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
num.remove(4)
print(num)
# Out:
# {1, 2, 5, 7, 8, 10}

# %%
num.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1510/1514787385.py in <cell line: 0>()
# ----> 1 num.remove(4)
#
# KeyError: 4

# %%
print(num)

# %%
item=num.pop()
print(item)
# Out:
# 1

# %%
print(num)
# Out:
# {2, 5, 7, 8, 10}

# %%
num.clear()

# %%
print(num)
# Out:
# set()

# %%
set()
# Out:
# set()

# %%
fruits
# Out:
# {'Apple', 'Banana', 'Mango'}

# %%
"Orange"in fruits
# Out:
# False

# %%
# union
A={1,2,3}
B={3,4,5}
print(A|B)
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersection
A={1,2,3}
B={3,4,5}
print(A&B)
# Out:
# {3}

# %%
#set difference
A={1,2,3}
B={3,4,5}
print(A-B)
# Out:
# {1, 2}

# %% [markdown]
# #Quiz

# %%
numbers={10,20,30,20,10}
total=0
for num in numbers:
  total+=num
print(total)
# Out:
# 60

# %%
fruits={"Apple","Banana"}
fruits.add("Mango")
fruits.add("Apple")
print(len(fruits))
# Out:
# 3

# %%
numbers={5,10,15}
numbers.remove(10)
print(sum(numbers))
# Out:
# 20

# %%
colors={"Red","Green","Blue"}
count=0
for color in colors:
  if "e" in color.lower():
    count+=1
print(count)
# Out:
# 3

# %%
numbers={2,4,6,8}
largesr=max(numbers)
smallest=min(numbers)
print(largesr-smallest)
# Out:
# 6

# %%
numbers=[10,20,20,30,10]
unique = set(numbers)
print(len(unique))
# Out:
# 3

# %%
fruits={"Apple","Banana"}
if "Mango" in fruits:
  print("Yes")
else:
  print("No")
# Out:
# No

# %%
cities={"Delhi","Mumbai"}
cities.add("Pune")
cities.remove("Delhi")
print(len(cities))
# Out:
# 2

# %%
text="banana"
letters=set(text)
print(len(letters))
# Out:
# 3

# %%
A={"Pythpn","Sql"}
B={"Python","Power BI"}
print(len(A&B))
# Out:
# 0

# %%
print(A&B)
# Out:
# set()

# %%
len({'Python'})
# Out:
# 1

# %%
numbers={5,10,15,20}
count=0
for num in numbers:
  if num>10:
    count+=1
print(count)
# Out:
# 2

# %% [markdown]
# #Hw

# %%
words=["apple","banana","apple","mango","banana"]
unique=set(words)
result=""
for word in unique:
    result+=words[0]
print(result)
# Out:
# appleappleapple

# %%
text="mississippi"
letters=set(text)
count=0
for ch in letters:
  if ch in "aeiou":
    count+=1
print(count)
# Out:
# 1

# %%
A={10,20,30}
B={30,40,50}
C=A.union(B)
print(min(C),max(C))
# Out:
# 10 50

# %%
numbers=[1,2,2,3,4,4,5]
unique=set(numbers)
even=set()
for num in unique:
  if num%2==0:
    even.add(num)
print(len(even))
# Out:
# 2

# %%
students={
    "Rahul",
    "Amit",
    "Neha"
}
students.remove("Amit")
students.add("Riya")
print(len(students))
# Out:
# 3

# %%
colors={" Red","Green","Blue"}
result=set()
for color in colors:
  result.add(color.upper())
print(len(result))
# Out:
# 3

# %%
numbers=[10,20,20,40,40,40]
A=set(numbers)
B={20,50}
result=A-B
print(sum(result))
# Out:
# 50
