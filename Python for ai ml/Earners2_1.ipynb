# %% [markdown]
# #Earners AI ML by Aditya Jain SIR-Lecture 2.1

# %% [markdown]
# ##Recap-Functions

# %%
def show():
  print("Hello Friends !")

# %%
show()
# Out:
# Hello Friends !

# %%
show()
# Out:
# Hello Friends !

# %%
def show(name, age):
  print("name is ",name)
  print("age is ",age)

# %%
show("Anjali", 22)
# Out:
# name is  Anjali
# age is  22

# %%
show(20,"Raj")
# Out:
# name is  20
# age is  Raj

# %%
#keyword aegument

# %%
show(age=20,name="Anjali")
# Out:
# name is  Anjali
# age is  20

# %%
#Default Arguments

# %%
def show(name="Raj"):
  print(name)

# %%
show()
# Out:
# Raj

# %%
show("AJ")
# Out:
# AJ

# %%
show()
# Out:
# Raj

# %% [markdown]
# ##HW

# %%
def check(num):
  if num%2==0:
    return "Even"
  else:
    return "odd"
print(check(15))
# Out:
# odd

# %%
print(check(20))
# Out:
# Even

# %%
def greet(name):
  print("Hello",name)
greet("Rahul")
# Out:
# Hello Rahul

# %%
def total(numbers):
  s=0
  for n in numbers:
    s+=n
  return s
print(total([5,10,15]))
# Out:
# 30

# %%
def display():
  return "Python"
print(display())
# Out:
# Python

# %%
def largest(a,b):
  if(a>b):
    return a
  else :
    return b
print(largest(12,25))
# Out:
# 25

# %% [markdown]
# #Dictionary

# %%
student={
    "name":"Anjlai",
    "age":22 ,
    "cgpa":91.5,
    "city ":"Nagpur"
    }

# %%
student
# Out:
# {'name': 'Anjlai', 'age': 22, 'cgpa': 91.5, 'city ': 'Nagpur'}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'Anjlai'

# %%
student["age"]
# Out:
# 22

# %%
student["cgpa"]
# Out:
# 91.5

# %%
student["age"]=23

# %%
print(student)
# Out:
# {'name': 'Anjlai', 'age': 23, 'cgpa': 91.5, 'city ': 'Nagpur'}

# %%
student["state"]="Maharashtra"

# %%
student
# Out:
# {'name': 'Anjlai',
#  'age': 23,
#  'cgpa': 91.5,
#  'city ': 'Nagpur',
#  'state': 'Maharashtra'}

# %%
student["age"]
# Out:
# 23

# %%
student.get("age")
# Out:
# 23

# %%
student.get("address")

# %%
student.get("address","key not found")
# Out:
# 'key not found'

# %%
student.get("age","key not found!")
# Out:
# 23

# %%
student
# Out:
# {'name': 'Anjlai',
#  'age': 23,
#  'cgpa': 91.5,
#  'city ': 'Nagpur',
#  'state': 'Maharashtra'}

# %%
student.pop("state")
# Out:
# 'Maharashtra'

# %%
student
# Out:
# {'name': 'Anjlai', 'age': 23, 'cgpa': 91.5, 'city ': 'Nagpur'}

# %% [markdown]
# #Loop Over Dictionaries

# %%
student
# Out:
# {'name': 'Anjlai', 'age': 23, 'cgpa': 91.5, 'city ': 'Nagpur'}

# %%
for k in student.keys():
  print(k)
# Out:
# name
# age
# cgpa
# city

# %%
for k in student.keys():
  print(student[k])
# Out:
# Anjlai
# 23
# 91.5
# Nagpur

# %%
for k in student.values():
  print(k)
# Out:
# Anjlai
# 23
# 91.5
# Nagpur

# %%
for elem in student.items():
  print(elem)
# Out:
# ('name', 'Anjlai')
# ('age', 23)
# ('cgpa', 91.5)
# ('city ', 'Nagpur')

# %%
for elem in student.items():
  print("key =",elem[0],"values=",elem[1])
# Out:
# key = name values= Anjlai
# key = age values= 23
# key = cgpa values= 91.5
# key = city  values= Nagpur

# %% [markdown]
# #Quiz

# %%
student={
    "name":"Rahul",
    "age":22
    }
print(student["name"])
# Out:
# Rahul

# %%
student={
    "name":"Rahul",
    "age":22
    }
print(student["age"])
# Out:
# 22

# %%
# which of the following correctly creates a dictionary?
# c. student={"name":"rahul"}

# %%
student={
    "name":"rahul"
}
student["age"]=22
print(student)
# Out:
# {'name': 'rahul', 'age': 22}

# %%
student={
    "name":"rahul"
}
student["age"]=23
print(student)
# Out:
# {'name': 'rahul', 'age': 23}

# %%
student={
    "name":"rahul"
}
student["age"]=22
print(len(student))
# Out:
# 2

# %%
student={
    "name":"rahul"
}
print(student.get("city"))
# Out:
# None

# %%
student.get("city")

# %%
student={
    "name":"rahul"
}
print(student["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_685/576019959.py in <cell line: 0>()
#       2     "name":"rahul"
#       3 }
# ----> 4 print(student["city"])
#
# KeyError: 'city'

# %%
student={
    "name:":"rahul",
    "age":22
}
print(student.keys())
# Out:
# dict_keys(['name:', 'age'])

# %%
student={
    "name:":"rahul",
    "age":22
}
print(student.values())
# Out:
# dict_values(['rahul', 22])

# %%
student={
    "name:":"rahul",
    "city":"Nagpur"
}
student.pop("city")
print(student)
# Out:
# {'name:': 'rahul'}

# %%
marks={
    "Math":90,
    "science":80,
    "english":95
}
total=0
for subject in marks.keys():
  total+=marks[subject]
print(total)
# Out:
# 265

# %%
cart={
    "Milk":2,
    "Bread":1
}
cart["Eggs"]=12
print(len(cart))
# Out:
# 3

# %%
employee={
    "salary":50000
}
employee["salary"]+=10000
print(employee["salary"])
# Out:
# 60000

# %%
student={
    "name":"Rahul",
    "age":22
}
count=0
for key in student.keys():
  count+=1
print(count)
# Out:
# 2

# %%
student={
    "name":"Rahul",
    "age":22
}
student["city"]="Nagpur"
student["age"]+=1
print(student["age"])
# Out:
# 23

# %%
marks={
    "Math":90,
    "Science":80,
    "English":70
}
total=0
for subject in marks.keys():
  total+=marks[subject]
print(total/len(marks))
# Out:
# 80.0

# %%
employee={
    "salary":50000
}
employee["salary"]=employee["salary"]*1.10
print(employee["salary"])
# Out:
# 55000.00000000001

# %%
# 10%=10/100
# x=x+0.1x=1.1x

# %%
data={
    "A":10,
    "B":20,
    "C":30
}
count=0
for key in data.keys():
  if(data[key]>15):
    count+=1
print(count)
# Out:
# 2

# %%
student={
    "name":"rahul",
    "age":22,
    "city":"Nagpur"
}
for key in student.keys():
  print(len(key))
# Out:
# 4
# 3
# 4

# %%
for k in student:
  print(k)
# Out:
# name
# age
# city

# %% [markdown]
# #Hw

# %%
fruit={
    "Apple":50,
    "Banana":20
}
fruit["Apple"]+=fruit["Banana"]
print(fruit["Apple"])
# Out:
# 70

# %%
student={
    "Math":90,
    "Science":85,
    "English":95
}
highest=0
for subject in student:
  if student[subject]>highest:
    heighest=student[subject]
print(highest)
# Out:
# 0

# %%
student={
    "name":"rahul",
    "age":"22"
}
student["age"]=student["age"]+len(student)
print(student["age"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_685/1233621701.py in <cell line: 0>()
#       3     "age":"22"
#       4 }
# ----> 5 student["age"]=student["age"]+len(student)
#       6 print(student["age"])
#
# TypeError: can only concatenate str (not "int") to str

# %%
data={}
data["A"]=10
data["B"]=20
data["A"]=30
print(len(data))
# Out:
# 2

# %%
student={
    "maths":80,
    "science":90,
    "english":85
}
count=0
for key in student:
  if student[key]>85:
    count+=1
print(count)
# Out:
# 1

# %%
person={
    "name":"amit",
    "age":25
}
person.pop("age")
person["age"]=30
print(person)
# Out:
# {'name': 'amit', 'age': 30}

# %%
marks={
    "Math":90,
    "science":80,
    "english":70
}
total=0
for subject in marks:
  if marks[subject]>=80:
    total+=marks[subject]
print(total)
# Out:
# 170

# %%
student={
    "math":95,
    "science":85
}
for key in student:
  print(key,student[key]//10)
# Out:
# math 9
# science 8

# %%
data={
    "A":5,
    "B":10,
    "C":15
}
result=0
for key in data:
  if data[key]%10==0:
    result+=1
print(result)
# Out:
# 1

# %%
student={
    "math":95,
    "science":80
}
student["Total"]=0
for key in student:
  if key!="Total":
    student["Total"]+=student[key]
print(student["Total"])
# Out:
# 175
